# %%
import random

# %%
random.randint(1,100)
# Out:
# 89

# %%
housing.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 housing.shape[0]
#
# NameError: name 'housing' is not defined

# %%
def sample_gen(df,sample_size):
    """
    what is doing

    args:

    outcome:
    
    raise:
    
    example:
    
    """
    no_rows=housing.shape[0]
    index_list=[]
    for index in range(sample_size):
        index_list.append(random.randint(0,no_rows))
    sample_df=df.loc[index_list]
    return sample_df

# %%
sample_gen(housing, 100)

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
housing=pd.read_csv('housing.csv') 
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.shape[0]
# Out:
# 20640

# %% [markdown]
# ## Simple random sampling

# %%
sample1=housing.sample(200) # selects 200 respenses
sample1.shape
# Out:
# (200, 10)

# %%
sample1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3326     -122.77     38.92                26.0        712.0           140.0
# 588      -122.10     37.70                25.0       2973.0           622.0
# 15119    -116.93     32.85                15.0       3273.0           895.0
# 10809    -117.94     33.64                18.0       1867.0           426.0
# 14856    -117.07     32.64                32.0       5135.0          1025.0
# ...          ...       ...                 ...          ...             ...
# 4865     -118.28     34.04                24.0       1283.0           545.0
# 12359    -116.53     33.78                18.0       2547.0           463.0
# 9518     -123.19     39.15                16.0       2577.0           495.0
# 18663    -121.94     37.00                32.0       2210.0           426.0
# 2549     -124.17     40.79                43.0       2285.0           479.0
#
#        population  households  median_income  median_house_value  \
# 3326        293.0       100.0         4.0119            119400.0
# 588        1413.0       595.0         4.3819            209200.0
# 15119      1872.0       842.0         2.5388            119000.0
# 10809       871.0       399.0         2.6221            272000.0
# 14856      2152.0       944.0         4.1325            172800.0
# ...           ...         ...            ...                 ...
# 4865       1932.0       516.0         1.2969            160200.0
# 12359       411.0       214.0         2.5489            220500.0
# 9518       1232.0       488.0         2.6012            125600.0
# 18663      1082.0       396.0         4.1587            315200.0
# 2549       1169.0       482.0         1.9688             70500.0
#
#       ocean_proximity
# 3326           INLAND
# 588          NEAR BAY
# 15119       <1H OCEAN
# 10809       <1H OCEAN
# 14856      NEAR OCEAN
# ...               ...
# 4865        <1H OCEAN
# 12359          INLAND
# 9518        <1H OCEAN
# 18663      NEAR OCEAN
# 2549       NEAR OCEAN
#
# [200 rows x 10 columns]

# %% [markdown]
# ## Systematics Sampling

# %%
def system_sample(data_frame,step_size):
    index_selected=np.arange(0,data_frame.shape[0],step=step_size)
    df_new=data_frame.iloc[index_selected]
    return df_new

# %%
list(np.arange(0,10,5)) #give you specific no. of elements in the range for a given step size(interval)
# Out:
# [np.int64(0), np.int64(5)]

# %%
np.linspace(0,10,5) # give you the quantity of elements that you specify: uniform distance from one another
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
# call the systematic sampling
system_sample(housing,15)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 15       -122.26     37.85                50.0       1120.0           283.0
# 30       -122.28     37.84                49.0       1916.0           447.0
# 45       -122.26     37.83                52.0       1656.0           420.0
# 60       -122.29     37.83                52.0       1121.0           211.0
# ...          ...       ...                 ...          ...             ...
# 20565    -121.70     38.65                22.0       1360.0           282.0
# 20580    -121.77     38.76                32.0       1950.0           385.0
# 20595    -121.56     39.16                12.0       3349.0           642.0
# 20610    -121.56     39.10                28.0       2130.0           484.0
# 20625    -121.52     39.12                37.0        102.0            17.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 15          697.0       264.0         2.1250            140000.0
# 30          863.0       378.0         1.9274            122300.0
# 45          718.0       382.0         2.6768            182300.0
# 60          554.0       187.0         3.3929             75700.0
# ...           ...         ...            ...                 ...
# 20565       808.0       229.0         2.4167            225000.0
# 20580      1145.0       363.0         2.8365             87900.0
# 20595      2029.0       619.0         2.9647             88800.0
# 20610      1195.0       439.0         1.3631             45500.0
# 20625        29.0        14.0         4.1250             72000.0
#
#       ocean_proximity
# 0            NEAR BAY
# 15           NEAR BAY
# 30           NEAR BAY
# 45           NEAR BAY
# 60           NEAR BAY
# ...               ...
# 20565          INLAND
# 20580          INLAND
# 20595          INLAND
# 20610          INLAND
# 20625          INLAND
#
# [1376 rows x 10 columns]

# %%
housing.iloc[::15,:]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 15       -122.26     37.85                50.0       1120.0           283.0
# 30       -122.28     37.84                49.0       1916.0           447.0
# 45       -122.26     37.83                52.0       1656.0           420.0
# 60       -122.29     37.83                52.0       1121.0           211.0
# ...          ...       ...                 ...          ...             ...
# 20565    -121.70     38.65                22.0       1360.0           282.0
# 20580    -121.77     38.76                32.0       1950.0           385.0
# 20595    -121.56     39.16                12.0       3349.0           642.0
# 20610    -121.56     39.10                28.0       2130.0           484.0
# 20625    -121.52     39.12                37.0        102.0            17.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 15          697.0       264.0         2.1250            140000.0
# 30          863.0       378.0         1.9274            122300.0
# 45          718.0       382.0         2.6768            182300.0
# 60          554.0       187.0         3.3929             75700.0
# ...           ...         ...            ...                 ...
# 20565       808.0       229.0         2.4167            225000.0
# 20580      1145.0       363.0         2.8365             87900.0
# 20595      2029.0       619.0         2.9647             88800.0
# 20610      1195.0       439.0         1.3631             45500.0
# 20625        29.0        14.0         4.1250             72000.0
#
#       ocean_proximity
# 0            NEAR BAY
# 15           NEAR BAY
# 30           NEAR BAY
# 45           NEAR BAY
# 60           NEAR BAY
# ...               ...
# 20565          INLAND
# 20580          INLAND
# 20595          INLAND
# 20610          INLAND
# 20625          INLAND
#
# [1376 rows x 10 columns]

# %% [markdown]
# ## Stratified sampling
#
# create strata based on some column then select the elements
#
# We want to predict the median housing based all those values

# %%
housing.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
y=housing['median_house_value']#Response variable

# %%
housing.iloc[:,:-1].head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0

# %%
#distribution of median house, Pick a dependent variable with high correlation as the response variable and split into strums
#data based on the distribution of
#those variable
housing.iloc[:,:-1].corr().iloc[:,-1].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688075
# total_rooms           0.134153
# housing_median_age    0.105623
# households            0.065843
# total_bedrooms        0.049686
# population           -0.024650
# longitude            -0.045967
# latitude             -0.144160
# Name: median_house_value, dtype: float64

# %%
#create new column
bin=np.linspace(housing['median_income'].min(),housing['median_income'].max(),10)
label=np.arange(0,9,1)
label1=list(range(0,9))
label1
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
housing['cut']=pd.cut(housing['median_income'], bins=bin, labels=label)
plt.hist(housing['cut']);

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
the_split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)

# %%
housing[['cut']]
# Out:
#       cut
# 0       4
# 1       4
# 2       4
# 3       3
# 4       2
# ...    ..
# 20635   0
# 20636   1
# 20637   0
# 20638   0
# 20639   1
#
# [20640 rows x 1 columns]

# %%
housing.head()

# %%
housing.shape

# %%
housing.dropna(inplace=True)

# %%
housing.shape

# %%
housing['cut']=pd.cut(housing['median_income'], bins=bin, labels=label)

# %%
for train_index,test_index in the_split.split(housing,housing['cut']):
    train_data=housing.iloc[train_index]
    test_data=housing.iloc[test_index]

# %%
test_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11824    -120.99     39.04                17.0       2289.0           450.0
# 3554     -118.60     34.23                19.0       8866.0          2355.0
# 2179     -119.90     36.79                22.0       1970.0           332.0
# 19871    -119.29     36.34                28.0       1440.0           431.0
# 11619    -118.04     33.84                21.0       6623.0          1204.0
# ...          ...       ...                 ...          ...             ...
# 9007     -118.60     34.09                43.0       2228.0           438.0
# 5403     -118.43     34.03                36.0       1552.0           388.0
# 13569    -117.28     34.14                40.0       2364.0           438.0
# 10067    -120.09     39.40                17.0       1076.0           283.0
# 16124    -122.47     37.78                52.0       2635.0           587.0
#
#        population  households  median_income  median_house_value  \
# 11824      1182.0       397.0         2.3696            166800.0
# 3554       5005.0      2194.0         3.2564            230300.0
# 2179       1066.0       319.0         3.3125            106100.0
# 19871      2178.0       440.0         1.2634             50600.0
# 11619      3193.0      1129.0         4.5395            256000.0
# ...           ...         ...            ...                 ...
# 9007        960.0       395.0         7.6091            438500.0
# 5403        867.0       352.0         3.6467            346700.0
# 13569       968.0       416.0         3.4906             93300.0
# 10067       171.0        64.0         2.1250             83900.0
# 16124      1302.0       577.0         3.7292            416700.0
#
#       ocean_proximity cut
# 11824          INLAND   1
# 3554        <1H OCEAN   1
# 2179           INLAND   1
# 19871          INLAND   0
# 11619       <1H OCEAN   2
# ...               ...  ..
# 9007        <1H OCEAN   4
# 5403        <1H OCEAN   1
# 13569          INLAND   1
# 10067          INLAND   1
# 16124        NEAR BAY   2
#
# [4085 rows x 11 columns]
